# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
path = "/pfs/10/work/hd_cu284-work/fargo3d/outputs/fargo_log_grid/" #2
paths = [path]

# %%
max_n =4

rho_cube=[] # first index: which alpha, second index: which snapshot.
for path in paths:
    rho_cube.append([])
    for i in range(max_n+1):
plt.imshow(rho_cube[0][-1],origin='lower', cmap=cm.Oranges_r, aspect='auto',extent=[0,2*np.pi,np.log10(r_min), np.log10(r_max)])
plt.title(f"$\\log \\Sigma$, {path[43:-5]}, {(frames[-1])*10} orbits")
plt.ylabel("$log10(r/r_0)$")
plt.colorbar()
        rho = np.fromfile(f"{path}/gasdens{i}.dat").reshape(300, 384) #500
        rho_cube[-1].append(rho)

rho_cube=np.array(rho_cube)

# %%
 49152/384
# Out:
# 128.0

# %%
# %matplotlib inline

frames = [1,4]
plt.figure(figsize=(len(frames)*6,5))


for i,frame in enumerate(frames):
    plt.subplot(1,len(frames),1+i)
    plt.imshow(np.log10(rho_cube[0][frame]), origin='lower', cmap=cm.Oranges_r, aspect='auto',extent=[0,2*np.pi,np.log10(0.4),np.log10(2.5)])
    plt.title(f"$\\log \\Sigma$, {frame*10} orbits")
    plt.colorbar()
    plt.xlabel("$\\varphi$")
    plt.ylabel("$\\log(r/r_p)$")

# %%
R_min = 0.2      
R_max = 20
Nr = 500
Nphi = 384

r_list = np.fromfile(f"{path}domain_y.dat", sep="\n")[3:-4]#R_min * (R_max / R_min)**(np.linspace(0, 1, Nr))
phi = np.linspace(0, 2*np.pi, Nphi)

R, PHI = np.meshgrid(r_list, phi, indexing='ij')

# %%
# %matplotlib inline

frames = [1,10]
plt.figure(figsize=(len(frames)*6,5))


for i,frame in enumerate(frames):
    plt.subplot(1,len(frames),1+i)
    
    plt.pcolormesh(PHI, R, np.log10(rho_cube[0][frame]),cmap=cm.Oranges_r, shading='auto')
    plt.xlabel("$\\varphi$")
    plt.ylabel("$r/r_p$")
    plt.title(f"$\\log \\Sigma$, {frame*10} orbits")
    plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 10
#       7 for i,frame in enumerate(frames):
#       8     plt.subplot(1,len(frames),1+i)
# ---> 10     plt.pcolormesh(PHI, R, np.log10(rho_cube[0][frame]),cmap=cm.Oranges_r, shading='auto')
#      11     plt.xlabel("$\\varphi$")
#      12     plt.ylabel("$r/r_p$")
#
# File ~/.conda/envs/kernel_env/lib/python3.12/site-packages/matplotlib/pyplot.py:3740, in pcolormesh(alpha, norm, cmap, vmin, vmax, colorizer, shading, antialiased, data, *args, **kwargs)
#    3726 @_copy_docstring_and_deprecators(Axes.pcolormesh)
#    3727 def pcolormesh(
#    3728     *args: ArrayLike,
#    (...)   3738     **kwargs,
#    3739 ) -> QuadMesh:
# -> 3740     __ret = gca().pcolormesh(
#    3741         *args,
#    3742         alpha=alpha,
#    3743         norm=norm,
#    3744         cmap=cmap,
#    3745         vmin=vmin,
#    3746         vmax=vmax,
#    3747         colorizer=colorizer,
#    3748         shading=shading,
#    3749         antialiased=antialiased,
#    3750         **({"data": data} if data is not None else {}),
#    3751         **kwargs,
#    3752     )
#    3753     sci(__ret)
#    3754     return __ret
#
# File ~/.conda/envs/kernel_env/lib/python3.12/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/.conda/envs/kernel_env/lib/python3.12/site-packages/matplotlib/axes/_axes.py:6528, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, colorizer, shading, antialiased, *args, **kwargs)
#    6525 shading = shading.lower()
#    6526 kwargs.setdefault('edgecolors', 'none')
# -> 6528 X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6529                                     shading=shading, kwargs=kwargs)
#    6530 coords = np.stack([X, Y], axis=-1)
#    6532 kwargs.setdefault('snap', mpl.rcParams['pcolormesh.snap'])
#
# File ~/.conda/envs/kernel_env/lib/python3.12/site-packages/matplotlib/axes/_axes.py:6060, in Axes._pcolorargs(self, funcname, shading, *args, **kwargs)
#    6058 if shading == 'flat':
#    6059     if (Nx, Ny) != (ncols + 1, nrows + 1):
# -> 6060         raise TypeError(f"Dimensions of C {C.shape} should"
#    6061                         f" be one smaller than X({Nx}) and Y({Ny})"
#    6062                         f" while using shading='flat'"
#    6063                         f" see help({funcname})")
#    6064 else:    # ['nearest', 'gouraud']:
#    6065     if (Nx, Ny) != (ncols, nrows):
#
# TypeError: Dimensions of C (128, 384) should be one smaller than X(384) and Y(300) while using shading='flat' see help(pcolormesh)
